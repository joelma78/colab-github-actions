# %% [markdown]
# <a href="https://colab.research.google.com/github/joelma78/colab-github-actions/blob/main/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas

import pandas as pd

dados = {
    "Aluno": ["Ana", "Bruno", "Carlos"],
    "Nota": [8.5, 7.0, 9.0]
}

df = pd.DataFrame(dados)

df["Resultado"] = df["Nota"].apply(
    lambda x: "Aprovado" if x >= 7 else "Reprovado"
)

df
# Out:
# ...
#     Aluno  Nota Resultado
# 0     Ana   8.5  Aprovado
# 1   Bruno   7.0  Aprovado
# 2  Carlos   9.0  Aprovado

# %%
print("quelegal")
# Out:
# quelegal
